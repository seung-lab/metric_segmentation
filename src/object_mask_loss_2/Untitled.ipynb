# %%
import numpy as np 
import tensorflow as tf 
import matplotlib.pyplot as plt 

import sys; sys.path.append('/usr/people/kluther/Projects/metric_segmentation/src/')
import provider

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data_dir = '/usr/people/kluther/Projects/metric_segmentation/data/'
p = provider.EMDataGenerator(data_dir, 'train', 10)

# %%
em_img, mask_list, _ = p.next_example(10)
em_img = em_img[92:480, 92:480]

# %%
plt.imshow(em_img[:,:,0], cmap='gray'); plt.show()
plt.imshow(mask_list[0][:,:,0], cmap='gray'); plt.show()
plt.imshow(em_img[:,:,0]*mask_list[0][:,:,0], cmap='gray'); plt.show()

# %%
em_img.shape
# Out:
# (388, 388, 1)
